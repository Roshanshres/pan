# %% [markdown]
# <a href="https://colab.research.google.com/github/Roshanshres/pandas/blob/main/17_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DataFrame Method
# 1 colum = series
# 1 row = series
# Table = dataframe

# %%
import numpy as np
import pandas as pd

# %%
#creating dataframe
#using list
students_data= [[100, 80,10],
[90,80,70],
[120, 110,80],
[80, 60,3]]
pd.DataFrame(students_data, columns = ['iq', 'marks', 'package'])
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     80       70
# 2  120    110       80
# 3   80     60        3

# %% [markdown]
# DataFrame using dictionaty

# %%
student_dic = {
    'iq': [100,90,80],
    'marks':[80, 90 , 60],
    'packages':[100, 70, 90]
}
pd.DataFrame(student_dic)
# Out:
#     iq  marks  packages
# 0  100     80       100
# 1   90     90        70
# 2   80     60        90

# %%
students = pd.DataFrame(student_dic)
students
# Out:
#     iq  marks  packages
# 0  100     80       100
# 1   90     90        70
# 2   80     60        90

# %% [markdown]
# new csv file or read_csv file

# %%
pd.read_csv("/content/ipl-matches.csv")
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
#using read_csv
pd.read_csv('/content/diabetes.csv')
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
diabetes = pd.read_csv('/content/diabetes.csv')
diabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
ipl =pd.read_csv('/content/ipl-matches.csv')
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
runs = pd.read_csv('/content/batsman_runs_ipl.csv')
runs
# Out:
#              batter  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 2        A Chandila            4
# 3          A Chopra           53
# 4       A Choudhary           25
# ..              ...          ...
# 600      Yash Dayal            0
# 601   Yashpal Singh           47
# 602     Younis Khan            3
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [605 rows x 2 columns]

# %% [markdown]
# DataFrame Attributes and Methods

# %%
#shapes
#no.of rows and no.of columns
diabetes.shape
# Out:
# (768, 9)

# %%
runs.shape
# Out:
# (605, 2)

# %%
ipl.shape
# Out:
# (950, 20)

# %%
#dtypes
# to see datatypes
ipl.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
diabetes.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
runs.dtypes
# Out:
# batter         object
# batsman_run     int64
# dtype: object

# %%
#index
ipl.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
#column
diabetes.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
#values
#fetch data from dataframe
students.values
# Out:
# array([[100,  80, 100],
#        [ 90,  90,  70],
#        [ 80,  60,  90]])

# %%
#head and tail

# %%
runs.head()
# Out:
#            batter  batsman_run
# 0  A Ashish Reddy          280
# 1        A Badoni          161
# 2      A Chandila            4
# 3        A Chopra           53
# 4     A Choudhary           25

# %%
runs.head(2)
# Out:
#            batter  batsman_run
# 0  A Ashish Reddy          280
# 1        A Badoni          161

# %%
#tail
ipl.tail()
# Out:
#          ID        City        Date   Season MatchNumber  \
# 945  335986     Kolkata  2008-04-20  2007/08           4
# 946  335985      Mumbai  2008-04-20  2007/08           5
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# ...

# %%
ipl.tail(5)
# Out:
#          ID        City        Date   Season MatchNumber  \
# 945  335986     Kolkata  2008-04-20  2007/08           4
# 946  335985      Mumbai  2008-04-20  2007/08           5
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# ...

# %%
#sample
#check where there is bios or not
students.sample()
# Out:
#    iq  marks  packages
# 1  90     90        70

# %%
ipl.sample()
# Out:
#          ID     City        Date Season MatchNumber                Team1  \
# 658  548352  Chennai  2012-05-04   2012          46  Chennai Super Kings
#
#                Team2                            Venue           TossWinner  \
# 658  Deccan Chargers  MA Chidambaram Stadium, Chepauk  Chennai Super Kings
#
#     TossDecision SuperOver          WinningTeam WonBy  Margin method  \
# 658          bat         N  Chennai Super Kings  Runs    10.0    NaN
#
#     Player_of_Match                                       Team1Players  \
# 658        SK Raina  ['F du Plessis', 'M Vijay', 'SK Raina', 'MS Dh...
#
#                                           Team2Players          Umpire1  \
# 658  ['PA Patel', 'S Dhawan', 'CL White', 'KC Sanga...  HDPK Dharmasena
#
#           Umpire2
# 658  BNJ Oxenford

# %%
ipl.sample(5)
# Out:
#           ID       City        Date Season MatchNumber                Team1  \
# 852   392222  Centurion  2009-05-12   2009          42      Kings XI Punjab
# 278  1136596  Hyderabad  2018-05-05   2018          36     Delhi Daredevils
# 275  1136599  Hyderabad  2018-05-07   2018          39  Sunrisers Hyderabad
# 590   598035     Raipur  2013-04-28   2013          39     Delhi Daredevils
# 448   829793     Raipur  2015-05-09   2015          45     Delhi Daredevils
#
#                            Team2  \
# 852               Mumbai Indians
# 278          Sunrisers Hyderabad
# 275  Royal Challengers Bangalore
# 590                Pune Warriors
# 448          Sunrisers Hyderabad
#
#                                                 Venue  \
# 852                                   SuperSport Park
# 278                Rajiv Gandhi International Stadium
# 275                Rajiv Gandhi International Stadium
# 590  Shaheed Veer Narayan Singh International Stadium
# ...

# %%
#info
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
#describe
ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %% [markdown]
# important and most used function in real-world

# %%
#isnull---> false = not null
ipl.isnull()
# Out:
#         ID   City   Date  Season  MatchNumber  Team1  Team2  Venue  \
# 0    False  False  False   False        False  False  False  False
# 1    False  False  False   False        False  False  False  False
# 2    False  False  False   False        False  False  False  False
# 3    False  False  False   False        False  False  False  False
# 4    False  False  False   False        False  False  False  False
# ..     ...    ...    ...     ...          ...    ...    ...    ...
# 945  False  False  False   False        False  False  False  False
# 946  False  False  False   False        False  False  False  False
# 947  False  False  False   False        False  False  False  False
# 948  False  False  False   False        False  False  False  False
# 949  False  False  False   False        False  False  False  False
#
#      TossWinner  TossDecision  SuperOver  WinningTeam  WonBy  Margin  method  \
# 0         False         False      False        False  False   False    True
# ...

# %%
ipl.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %% [markdown]
# Duplicated\
#
# ```
# #to check duplication inside dataframe
# there shouldnot be repeatation
#
# ```

# %%
diabetes.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 763    False
# 764    False
# 765    False
# 766    False
# 767    False
# Length: 768, dtype: bool

# %%
#to find the numbers of duplication
diabetes.duplicated().sum()
# Out:
# 0

# %%
students.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %%
students.duplicated().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of 0    False
# 1    False
# 2    False
# dtype: bool>

# %%
students
# Out:
#     iq  marks  packages
# 0  100     80       100
# 1   90     90        70
# 2   80     60        90

# %%
#rename
#to rename columns name
students.rename(columns={'marks':'percentage','packages':'LPA'})
# Out:
#     iq  percentage  LPA
# 0  100          80  100
# 1   90          90   70
# 2   80          60   90

# %%
#for percentages
students.rename(columns= {'marks':'percentage','packages':'LPA'},inplace=True)

# %%
students
# Out:
#     iq  percentage  LPA
# 0  100          80  100
# 1   90          90   70
# 2   80          60   90

# %% [markdown]
# Maths Methods
# ## sum - axis argument
# sum/min/max/mean/median

# %%
diabetes.sum()#concatenate
# Out:
# Pregnancies                  2953.000
# Glucose                     92847.000
# BloodPressure               53073.000
# SkinThickness               15772.000
# Insulin                     61286.000
# BMI                         24570.300
# DiabetesPedigreeFunction      362.401
# Age                         25529.000
# Outcome                       268.000
# dtype: float64

# %%
#rows
diabetes.sum(axis=1)
# Out:
# 0      346.227
# 1      238.951
# 2      311.972
# 3      322.267
# 4      459.388
#         ...
# 763    511.071
# 764    285.140
# 765    389.445
# 766    265.449
# 767    248.715
# Length: 768, dtype: float64

# %%
diabetes.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
ipl.median()
# Out:
# <ipython-input-42-12d22a31b0aa>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ipl.median()
# ID        829738.0
# Margin         8.0
# dtype: float64

# %%
runs.std()
# Out:
# <ipython-input-43-8f64973b100b>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   runs.std()
# batsman_run    985.272855
# dtype: float64

# %%
ipl.var()
# Out:
# <ipython-input-44-e02e4b62e74f>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ipl.var()
# ID        1.139520e+11
# Margin    4.679914e+02
# dtype: float64

# %%
#selecting columns from a DataFrame
#fetch 1 single column from table


#single columns
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl['Venue']
# Out:
# 0                Narendra Modi Stadium, Ahmedabad
# 1                Narendra Modi Stadium, Ahmedabad
# 2                           Eden Gardens, Kolkata
# 3                           Eden Gardens, Kolkata
# 4                        Wankhede Stadium, Mumbai
#                           ...
# 945                                  Eden Gardens
# 946                              Wankhede Stadium
# 947                              Feroz Shah Kotla
# 948    Punjab Cricket Association Stadium, Mohali
# 949                         M Chinnaswamy Stadium
# Name: Venue, Length: 950, dtype: object

# %%
#multiple columns
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl[['Team1', 'Team2', 'WinningTeam']]
# Out:
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                      WinningTeam
# 0                 Gujarat Titans
# 1               Rajasthan Royals
# 2    Royal Challengers Bangalore
# 3                 Gujarat Titans
# 4                   Punjab Kings
# ...

# %%
type(ipl[['Team1', 'Team2', 'WinningTeam']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# how to fetch rows =
# selecting rows from DataFrame

# %%
#changing in student
student_dict={
    'name':['Roshan', 'Hira', 'Ramesh','Hari','Rajesh']
}
students
# Out:
#     iq  percentage  LPA
# 0  100          80  100
# 1   90          90   70
# 2   80          60   90

# %%
student.set_index('name', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-895f74ba1937> in <cell line: 1>()
# ----> 1 student.set_index('name', inplace=True)
#
# NameError: name 'student' is not defined

# %% [markdown]
# Fetch rows from dataset
#
#
# 1.   iloc= search using index positions.
# 2.   loc = search using index labels.

# %%
#single row
ipl.iloc[0]

# %%
type[ipl.iloc[4]]

# %%
#multiples
ipl.iloc[0:5] # 5 is not included

# %%
#alternate
ipl.iloc[4:18:2]

# %%
ipl.iloc[:19]

# %% [markdown]
# LOC or location
# It depends on location of index

# %%
#loc or loacations
students.loc['nitesh']

# %%
students

# %%
#fetch rows and column together
ipl.iloc[0:3, 0:3]

# %% [markdown]
# #Filtering a dataframe
# it is very important topic we mostly used

# %% [markdown]
# #using logical condition
# #find all the final winner
# 1, final value
# winner team

# %%
ipl

# %%
ipl['MatchNumber'] == 'Final'

# %%
mask = ipl['MatchNumber'] =='Final'
mask
ipl[mask]

# %%
#new DataFramem
mask = ipl['MatchNumber'] =='Final'
new_df = ipl[mask]
new_df[['Season', 'WinningTeam']]#called fancy indexing

# %%
#how many super-over have occurs

ipl['SuperOver']=='Y'
ipl[ipl['SuperOver']=='Y']

# %%
#how many super-over have occurs

ipl['SuperOver']=='Y'
ipl[ipl['SuperOver']=='Y']
ipl[ipl['SuperOver'] == 'Y'].shape[0]
# Out:
# 14

# %%
#how many matches has csk won in kolkota
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
ipl['City'] =='Kolkata'
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 945     True
# 946    False
# 947    False
# 948    False
# 949    False
# Name: City, Length: 950, dtype: bool

# %%
ipl[ipl['City'] == 'Kolkata']

# %%
ipl[(ipl['City']=='Kolkata') & (ipl['WinningTeam']=='Chennai Super Kings')]
# Out:
#           ID     City        Date   Season MatchNumber                  Team1  \
# 224  1178404  Kolkata  2019-04-14     2019          29  Kolkata Knight Riders
# 602   598022  Kolkata  2013-04-20     2013          26  Kolkata Knight Riders
# 641   548368  Kolkata  2012-05-14     2012          63  Kolkata Knight Riders
# 827   419113  Kolkata  2010-03-16  2009/10           8  Kolkata Knight Riders
# 908   336025  Kolkata  2008-05-18  2007/08          41  Kolkata Knight Riders
#
#                    Team2         Venue             TossWinner TossDecision  \
# 224  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 602  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
# 641  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 827  Chennai Super Kings  Eden Gardens    Chennai Super Kings          bat
# 908  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
#
# ...

# %%
ipl[(ipl['City']=='Kolkata') &(ipl['WinningTeam']=='Chennai Super Kings')].shape[0]
# Out:
# 5

# %%
#
diabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#toss winner ia the match winner in percentage of ipl
ipl['TossWinner']==ipl['WinningTeam']
ipl[ipl['TossWinner']==ipl['WinningTeam']]

# %%
ipl[ipl['TossWinner'] == ipl ['WinningTeam']].shape[0]
# Out:
# 489

# %%
#into percentages
(ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0]/ipl.shape[0])* 100
# Out:
# 51.473684210526315

# %%
#diabete
#glucose grater than 120 ages  > 25
diabetes.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
(diabetes['Glucose'] > 120) & (diabetes['Age']> 25)
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 763    False
# 764     True
# 765     True
# 766     True
# 767    False
# Length: 768, dtype: bool

# %%
diabetes[(diabetes['Glucose'] > 120) & (diabetes['Age'] > 25)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# ..           ...      ...            ...            ...      ...   ...
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
diabetes[(diabetes['Glucose'] > 120) & (diabetes['Age'] > 25)].shape[0]
# Out:
# 267

# %%
#write a fucntions that can return the track record of 2 team against each other

# %%
#how to add new column in DF
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl['Country']=  'India'
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  ...  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat  ...
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field  ...
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field  ...
# ...

# %%
#for existing
ipl['WinningTeam].str.split(|)
# Out:
#   File "<ipython-input-93-b230ddd00f4f>", line 2
#     ipl['WinningTeam].str.split(|)
#         ^
# SyntaxError: unterminated string literal (detected at line 2)

# %% [markdown]
# important DataFrame Functions

# %%
#astype
#changes the DataType of given column
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
#inr64 to 32
ipl['ID'].astype('int32')
# Out:
# 0      1312200
# 1      1312199
# 2      1312198
# 3      1312197
# 4      1304116
#         ...
# 945     335986
# 946     335985
# 947     335984
# 948     335983
# 949     335982
# Name: ID, Length: 950, dtype: int32

# %%
ipl['ID'] = ipl['ID'].astype('int32')

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
#ipl session
ipl['Season'].astype('category')
# Out:
# 0         2022
# 1         2022
# 2         2022
# 3         2022
# 4         2022
#         ...
# 945    2007/08
# 946    2007/08
# 947    2007/08
# 948    2007/08
# 949    2007/08
# Name: Season, Length: 950, dtype: category
# Categories (15, object): ['2007/08', '2009', '2009/10', '2011', ..., '2019', '2020/21', '2021', '2022']

# %%
ipl['Season'] = ipl['Season'].astype('category')

# %%
ipl['Season']
# Out:
# 0         2022
# 1         2022
# 2         2022
# 3         2022
# 4         2022
#         ...
# 945    2007/08
# 946    2007/08
# 947    2007/08
# 948    2007/08
# 949    2007/08
# Name: Season, Length: 950, dtype: category
# Categories (15, object): ['2007/08', '2009', '2009/10', '2011', ..., '2019', '2020/21', '2021', '2022']

# %%
#team 1 ra 2 pani4

ipl['Team1'] = ipl['Team1'].astype('category')
ipl['Team2'] = ipl['Team2'].astype('category')

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    category
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    category
#  6   Team2            950 non-null    category
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...
