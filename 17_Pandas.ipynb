# %% [markdown]
# <a href="https://colab.research.google.com/github/Roshanshres/pandas/blob/main/17_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DataFrame Method
# 1 colum = series
# 1 row = series
# Table = dataframe

# %%
import numpy as np
import pandas as pd

# %%
#creating dataframe
#using list
students_data= [[100, 80,10],
[90,80,70],
[120, 110,80],
[80, 60,3]]
pd.DataFrame(students_data, columns = ['iq', 'marks', 'package'])
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     80       70
# 2  120    110       80
# 3   80     60        3

# %% [markdown]
# DataFrame using dictionaty

# %%
student_dic = {
    'iq': [100,90,80],
    'marks':[80, 90 , 60],
    'packages':[100, 70, 90]
}
pd.DataFrame(student_dic)
# Out:
#     iq  marks  packages
# 0  100     80       100
# 1   90     90        70
# 2   80     60        90
